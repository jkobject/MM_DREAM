# %%
# test file
import synapseclient
import pandas as pd
from genepy.utils import helper as ghelp

SYN_LOGIN = 'jkobject'
SYN_PASSWORD = "QXAxTW2s4AcRjaz"
syn = synapseclient.Synapse() 
syn.login(SYN_LOGIN,SYN_PASSWORD) 

# Obtain a pointer and download the data 
# loading the DREAM Challenge MM RNAseq dataset from Synapse
# dataset analysed with Salmon (reference-free mapper),
# using hg19 gene annotation annotated with ENTREZ id + ERCC (likely ERCC92) which is the spike-in gene which are not present here
syn9744875 = syn.get(entity='syn9744875')
syn9744732 = syn.get(entity='syn9744732')
syn9926878 = syn.get(entity='syn9926878')

rna_data = pd.read_csv(syn9744875.path, sep='\t', index_col=0)
clinical_data = pd.read_csv(syn9926878.path, sep=',').set_index('Patient')
explanation = pd.read_csv(syn9744732.path, sep=',', index_col=0)
# Out:
# Welcome, jkobject!

# %%
clinical_data = pd.read_csv(syn9926878.path, sep=',').set_index('Patient')

# %%
clinical_data[['D_OS','D_OS_FLAG','HR_FLAG','D_PFS', 'D_PFS_FLAG']]
# Out:
#            D_OS  D_OS_FLAG   HR_FLAG  D_PFS  D_PFS_FLAG
# Patient
# MMRF_1021  1575          0     FALSE    623           1
# MMRF_1029   995          0     FALSE    995           0
# MMRF_1030  1572          0     FALSE   1572           0
# MMRF_1031  1581          0     FALSE   1329           1
# MMRF_1032   934          1     FALSE    908           1
# ...         ...        ...       ...    ...         ...
# MMRF_2608   335          0  CENSORED    335           0
# MMRF_2611   247          0  CENSORED    246           0
# MMRF_2613   253          0  CENSORED    253           0
# MMRF_2614   290          0  CENSORED    290           0
# MMRF_2622   260          0  CENSORED    260           0
#
# [583 rows x 5 columns]

# %%
explanation.loc[set(clinical_data.columns) & set(explanation.index)]
# Out:
#                category       type controlled_values  \
# names
# D_OS_FLAG      response    Numeric   0="No"; 1="Yes"
# D_PFS          response    Numeric               NaN
# D_Age       demographic    Numeric               NaN
# D_Gender    demographic     Factor      Male; Female
# D_OS           response    Numeric               NaN
# D_ISS          response     Factor           1; 2; 3
# Patient              id  Character               NaN
# D_PFS_FLAG     response    Numeric   0="No"; 1="Yes"
#
#                                                   description  \
# names
# D_OS_FLAG                            Is the patient deceased?
# D_PFS       Progression-free survival: number of days from...
# D_Age                                Age at diagnosis (years)
# D_Gender                                        Gender string
# D_OS        Overall Survival time: number of days from (tr...
# D_ISS                                       ISS Disease Stage
# Patient            Normalized patient identification number.
# D_PFS_FLAG  Has the patient developed progressive disease ...
#
#                                                      MMRF_IA8  \
# names
# D_OS_FLAG                         STAND_ALONE_SURVIVAL.censos
# D_PFS                             STAND_ALONE_SURVIVAL.ttcpfs
# D_Age                                   PER_PATIENT::D_PT_age
# D_Gender                            PER_PATIENT::DEMOG_GENDER
# D_OS                               STAND_ALONE_SURVIVAL.ttcos
# D_ISS                                   PER_PATIENT::D_PT_iss
# Patient     MMRF_CoMMpass_IA8b_Seq_QC_Summary::Patients..K...
# D_PFS_FLAG                       STAND_ALONE_SURVIVAL.censpfs
#
#                                   GSE15695_UAMS  \
# names
# D_OS_FLAG                                   NaN
# D_PFS                                       NaN
# D_Age       GSE15695_My9_GEP_clinical_data::age
# D_Gender    GSE15695_My9_GEP_clinical_data::sex
# D_OS                                        NaN
# D_ISS       GSE15695_My9_GEP_clinical_data::iss
# Patient                            Array number
# D_PFS_FLAG                                  NaN
#
#                                                      Hose  \
# names
# D_OS_FLAG                                       OS_STATUS
# D_PFS            as.integer(as.numeric(EFS) /12 * 365.25)
# D_Age                                                 age
# D_Gender    recode(sex, "male"="Male", "female"="Female")
# D_OS                          as.numeric(OS) /12 * 365.25
# D_ISS                                                 ISS
# Patient                                               NaN
# D_PFS_FLAG                                     EFS_STATUS
#
#                                             UAMS.UK.MyelomaXI  \
# names
# D_OS_FLAG                                           OS_status
# D_PFS                                    PFS_months/12*365.25
# D_Age                                                     Age
# D_Gender    ifelse(grepl("M",toupper(df$Gender) ), "Male",...
# D_OS                                      OS_months/12*365.25
# D_ISS       ISS column. `Stage I` = 1, `Stage II` = 2, `St...
# Patient                                    format "UAMS_0000"
# D_PFS_FLAG                                         PFS_status
#
#                                    M2GEN  active
# names
# D_OS_FLAG                            NaN     1.0
# D_PFS                                NaN     1.0
# D_Age       Demographics::AgeAtDiagnosis     1.0
# D_Gender            Demographics::Gender     1.0
# D_OS                                 NaN     1.0
# D_ISS                                NaN     1.0
# Patient               Celgene Pt 1 = “1”     1.0
# D_PFS_FLAG                           NaN     1.0

# %%
clinical_labels = {"D_OS": 'survival_days', "D_OS_FLAG": 'is_deceased', "D_PFS": 'pfs_days', "D_PFS_FLAG": 'has_progressed', "HR_FLAG": 'to_pred'}
clinical_features = {'D_Age': 'age', 'D_Gender': 'sex', 'D_ISS': 'stage'}

# %%
clinical_data = clinical_data.rename(columns={**clinical_labels,**clinical_features})
# 
unc_clinical_data = clinical_data[clinical_data.to_pred!='CENSORED']
# subsetting columns
clinical_data = clinical_data[list(clinical_features.values()) + list(clinical_labels.values())]

unc_clinical_data = unc_clinical_data[list(clinical_features.values()) + list(clinical_labels.values())]

# %%
clinical_data
# Out:
#            age     sex  stage  survival_days  has_survived  pfs_days  \
# Patient
# MMRF_1021   54  Female    1.0           1575             0       623
# MMRF_1029   46    Male    1.0            995             0       995
# MMRF_1030   65  Female    1.0           1572             0      1572
# MMRF_1031   62    Male    1.0           1581             0      1329
# MMRF_1032   76    Male    2.0            934             1       908
# ...        ...     ...    ...            ...           ...       ...
# MMRF_2535   46  Female    3.0            354             0       354
# MMRF_2554   65    Male    1.0            271             1       271
# MMRF_2557   83    Male    3.0            325             1       131
# MMRF_2562   66    Male    2.0            269             0       199
# MMRF_2596   73  Female    1.0            139             1       139
#
#            has_progressed to_pred
# Patient
# MMRF_1021               1   FALSE
# MMRF_1029               0   FALSE
# MMRF_1030               0   FALSE
# MMRF_1031               1   FALSE
# MMRF_1032               1   FALSE
# ...                   ...     ...
# MMRF_2535               1    TRUE
# MMRF_2554               1    TRUE
# MMRF_2557               1    TRUE
# MMRF_2562               1    TRUE
# MMRF_2596               1    TRUE
#
# [392 rows x 8 columns]

# %%
gene_names = ghelp.generateGeneNames()
# Out:
# downloading gene names from biomart

# %%
gene_names = gene_names[gene_names.gene_biotype=='protein_coding'].set_index('ensembl_gene_id')

# %%
gene_names[gene_names.hgnc_symbol=="IKBKG"]
# Out:
#        ensembl_gene_id clone_based_ensembl_gene hgnc_symbol    gene_biotype  \
# 36069  ENSG00000269335                      NaN       IKBKG  protein_coding
#
#        entrezgene_id
# 36069         8517.0

# %%
rna_data = rna_data.loc[set(gene_names.index) & set(rna_data.index)]
# Out:
# [WARNING] <ipython-input-6-1ea5841ac759>:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   rna_data = rna_data.loc[set(gene_names.index) & set(rna_data.index)]

# %%
rna_data.index = [gene_names.loc[val]['hgnc_symbol'] if type(gene_names.loc[val]['hgnc_symbol']) is str else gene_names.loc[val].iloc[0]['hgnc_symbol'] for val in rna_data.index]

# %%
# sorting to get the latest rnaseq available for a patient. By postulating that the number is equal to the timepoint at sampling 
col = list(rna_data.columns)
col.sort()
rna_data = rna_data[col]

# %%
rna_data.columns =  ['_'.join(i.split('_')[:2]) for i in rna_data.columns]

# %%
for val in ghelp.dups(rna_data.columns):
    loc = rna_data[val].iloc[:,-1]
    rna_data.drop(val, axis=1, inplace=True)
    rna_data[val] = loc.values

# %%
len(clinical_data[clinical_data['stage'].isna()])
# Out:
# 15

# %%
clinical_data = clinical_data[~clinical_data['stage'].isna()]
unc_clinical_data = unc_clinical_data[~unc_clinical_data['stage'].isna()]

# %%
clinical_data[clinical_features.values()].replace({'Female': 1, 'Male': 0}).astype(int)
# Out:
#            age  sex  stage
# Patient
# MMRF_1021   54    1      1
# MMRF_1029   46    0      1
# MMRF_1030   65    1      1
# MMRF_1031   62    0      1
# MMRF_1032   76    0      2
# ...        ...  ...    ...
# MMRF_2608   67    0      1
# MMRF_2611   66    1      2
# MMRF_2613   70    1      2
# MMRF_2614   58    0      1
# MMRF_2622   59    0      2
#
# [563 rows x 3 columns]

# %%
to_add_tot = clinical_data[clinical_features.values()].replace({'Female': 1, 'Male': 0}).astype(int)
to_add = unc_clinical_data[clinical_features.values()].replace({'Female': 1, 'Male': 0}).astype(int)

# %%
Xtot = rna_data.T.loc[list(set(clinical_data.index))]
X = rna_data.T.loc[list(set(unc_clinical_data.index))]

# %%
X = pd.concat([X, to_add], axis=1)
Xtot = pd.concat([Xtot, to_add], axis=1)

# %%
on = ['age', 'stage', 'PHF19', 'BCL2A1']

# %%
X = X[~X.age.isna()]
Xtot = Xtot[~Xtot.age.isna()]

# %%
Ytot = clinical_data.replace({'FALSE':0, 'TRUE': 1})['to_pred'].loc[Xtot.index].values
Y = unc_clinical_data.replace({'FALSE':0, 'TRUE': 1})['to_pred'].loc[X.index].values

# %% [markdown]
# - 0.55 RF without any preprocessing
# - 0.70 RF with preprocessing and feature selection (60 estimators)
# - 0.71 SVM with preprocessing and feature selection <-- best model
# - 0.70 KNN (15 neighboors)

# %%
from sklearn import preprocessing
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support, plot_roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot as plt

# %%
scaler = preprocessing.StandardScaler().fit(X[on].values)
X_scaled = scaler.transform(X[on].values)

# %%
clf = RandomForestClassifier(n_estimators=60)
clf = clf.fit(X.values, Y)
scores = cross_val_score(clf, X.values, Y, cv=10)
print(scores.mean())
clf = svm.SVC()
clf = clf.fit(X_scaled, Y)
scores = cross_val_score(clf, X_scaled, Y, cv=100)
print(scores.mean())
clf = KNeighborsClassifier(n_neighbors=15)
clf = clf.fit(X_scaled, Y)
scores = cross_val_score(clf, X_scaled, Y, cv=100)
print(scores.mean())
#print(roc_auc_score)

# %%
pathways = {}
with open('../data/MMpathways.gmt') as f:
    for val in f.read().splitlines():
        pathways[val.split('\t')[0]] = val.split('\t')[2:]

# %%
xcol = set(X.columns)
for k, val in pathways.items():
    pathways[k] = set(val) & set(xcol)

# %%
for k, val in pathways.items():
  print(k + '\t\t' + '\t'.join(val))

# %%
X[n_on]
# Out:
#            age  stage     PHF19     BCL2A1  BIOCARTA_DEATH_PATHWAY  \
# MMRF_1352   54      1   6.31919  13.568500             2866.086424
# MMRF_1129   81      1   7.18572   1.209860              737.996327
# MMRF_1810   61      1   2.49794   3.856020             1222.206699
# MMRF_1785   63      2   3.25180   0.786432             1445.148344
# MMRF_1128   48      2   5.81664   0.773915             1494.895257
# ...        ...    ...       ...        ...                     ...
# MMRF_1389   51      1  44.22560   1.432170             1377.126964
# MMRF_1408   62      1   4.34635   1.921100             1787.513413
# MMRF_1595   73      3  25.81940   3.132240              625.508333
# MMRF_1842   56      1  16.53250   1.484660              516.779437
# MMRF_1484   72      2  12.86350   3.428210             1282.414264
#
#            BIOCARTA_CELLCYCLE_PATHWAY  BIOCARTA_ERK_PATHWAY  \
# MMRF_1352                  673.915382            802.649014
# MMRF_1129                 1550.433938            914.929662
# MMRF_1810                  344.416818            627.656737
# MMRF_1785                  305.034481            555.618100
# MMRF_1128                  456.538720           1025.268052
# ...                               ...                   ...
# MMRF_1389                 1980.427120           1484.809212
# MMRF_1408                  415.865560           1407.362277
# MMRF_1595                  761.714368           1493.747266
# MMRF_1842                 2616.813635            619.616417
# MMRF_1484                 1599.172461           1875.362976
#
#            BIOCARTA_NFKB_PATHWAY  BIOCARTA_P53_PATHWAY  BIOCARTA_RAS_PATHWAY  \
# MMRF_1352            2661.420722            730.066642            430.717218
# MMRF_1129             305.889994            369.731787            362.483192
# MMRF_1810             635.670645            550.364840            408.042497
# MMRF_1785             886.612343            423.421963            229.433822
# MMRF_1128             772.070390            592.951553            496.770100
# ...                          ...                   ...                   ...
# MMRF_1389             899.966106            892.254494            831.786347
# MMRF_1408            1369.842546            653.018651            574.535040
# MMRF_1595             229.816961            733.586214            596.737970
# MMRF_1842             311.274459           2666.624632            437.169484
# MMRF_1484             852.026769           1660.475672            545.785454
#
#            BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY  \
# MMRF_1352                                      508.653138
# MMRF_1129                                      518.277570
# MMRF_1810                                      433.214811
# MMRF_1785                                      293.271184
# MMRF_1128                                      446.806457
# ...                                                   ...
# MMRF_1389                                     1184.786626
# MMRF_1408                                      753.753668
# MMRF_1595                                      714.206872
# MMRF_1842                                      498.823244
# MMRF_1484                                      699.298812
#
#            REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATION  \
# MMRF_1352                                       10701.821326
# MMRF_1129                                        8635.356466
# MMRF_1810                                       10009.092188
# MMRF_1785                                        7176.345225
# MMRF_1128                                        9227.201765
# ...                                                      ...
# MMRF_1389                                       13387.653518
# MMRF_1408                                       13723.755119
# MMRF_1595                                       11117.265803
# MMRF_1842                                        7936.934167
# MMRF_1484                                       12657.481462
#
#            REACTOME_DNA_REPAIR      UAMS17  THALIDOMIDE
# MMRF_1352          9876.652466  229.780274     0.033935
# MMRF_1129          7676.810303  248.365437     0.518360
# MMRF_1810          9057.771342  241.139141     0.264916
# MMRF_1785          6547.343050  187.754666     0.023544
# MMRF_1128          9710.906308  267.777950     0.700733
# ...                        ...         ...          ...
# MMRF_1389         11673.586937  584.153136     2.420517
# MMRF_1408         13389.759449  216.722483     0.224549
# MMRF_1595         10638.015619  409.549910     2.521740
# MMRF_1842          7964.515266  228.177546     0.928542
# MMRF_1484         10998.189648  301.211181     0.575744
#
# [377 rows x 15 columns]

# %%
xcol = set(X.columns)
for k, val in pathways.items():
    X[k] = X[set(val) & xcol].sum(axis=1)
    Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
# Out:
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   X[k] = X[set(val) & xcol].sum(axis=1)
#
# [WARNING] <ipython-input-99-4cccefe00753>:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Xtot[k] = Xtot[set(val) & xcol].sum(axis=1)

# %%
rna_data[rna_data.var(1)!=0]
# Out:
#           MMRF_1021  MMRF_1029  MMRF_1030   MMRF_1031   MMRF_1032  MMRF_1033  \
# PRR20A     0.003496   0.000000   0.000000    0.000000    0.000000   0.000000
# TWSG1      8.710340  13.833500  11.625100   17.803900   14.306000   2.805780
# CTSZ     114.813000  87.726500  98.401200  124.376000  114.800000  71.203800
# DAP       27.807900  42.272400  30.955200   63.403700   55.063700  29.681000
# FBXO17     0.887648   0.000000   0.000000    0.007776    0.000000   0.664490
# ...             ...        ...        ...         ...         ...        ...
# LAMTOR5   21.369300  33.913000  21.715700   32.832500   39.960100  12.710400
# TAF4B      2.121040   5.624080   4.738660    4.221980    6.308060   2.426440
# TMEM71     0.081443   0.009403   0.060323    0.073700    0.155082   0.350505
# NCOA7     12.205900   6.704110  17.569800    5.404000   24.759000   8.805900
# HSBP1      5.673470  10.625700   5.282300   10.551100    8.659900   2.366750
#
#           MMRF_1037  MMRF_1038  MMRF_1045   MMRF_1048  ...   MMRF_2039  \
# PRR20A     0.000000   0.000000   0.000000    0.000000  ...    0.000000
# TWSG1      6.105020   7.966150   2.534890    7.745060  ...    2.666170
# CTSZ     105.645000  86.679900  43.363500  254.166000  ...   66.604100
# DAP       37.366700  28.219900  31.852300   42.421900  ...   37.478200
# FBXO17     0.029086   0.000000   0.000000    0.304403  ...    0.053398
# ...             ...        ...        ...         ...  ...         ...
# LAMTOR5   15.357400  18.842900  29.412000   52.284200  ...  102.834000
# TAF4B      3.676090   4.573890   2.706180    4.705140  ...    8.688400
# TMEM71     0.026476   0.065309   0.029972    0.042702  ...   14.752300
# NCOA7      7.195110   7.010970   6.108030    5.586340  ...    4.079070
# HSBP1      3.586110   3.905170   8.037330   14.288300  ...   10.488000
#
#          MMRF_1229   MMRF_1778  MMRF_2419   MMRF_1518   MMRF_1242  MMRF_1309  \
# PRR20A    0.000000    0.001004    0.00000    0.000000    0.000000   0.000000
# TWSG1     7.636830    5.060380    3.50387   10.327100    9.305590   3.138180
# CTSZ     73.373200  104.911000   92.37380   33.193400   34.519000  87.932800
# DAP      39.268100   43.820700   51.28680  178.879000   59.522100  43.837900
# FBXO17    0.000000    0.011038    0.00692    0.020416    0.012234   0.021565
# ...            ...         ...        ...         ...         ...        ...
# LAMTOR5  31.178200   36.783300   28.55250  116.315000  103.653000  29.280100
# TAF4B     3.126980    1.936900   13.54450   14.304700   14.490900   2.273250
# TMEM71    0.372537    1.993330    0.12047    0.155042    0.430852   0.104637
# NCOA7     5.218330    3.096100    8.42927    6.963350    7.180880   2.349870
# HSBP1     6.758520   15.118500    8.59840   29.112000   22.549000   8.789990
#
#          MMRF_1587  MMRF_2089   MMRF_1284
# PRR20A    0.000000   0.537420    0.000000
# TWSG1     8.548180   2.752980    5.902170
# CTSZ     65.334100  53.350200  272.343000
# DAP      58.539800  95.487300   33.553400
# FBXO17    0.045469   0.000000    0.142358
# ...            ...        ...         ...
# LAMTOR5  63.515300  39.761900   37.363900
# TAF4B    17.521900  10.796400    5.274280
# TMEM71    0.334475   0.032953    2.903960
# NCOA7     9.165860   3.022900   16.645600
# HSBP1    22.914700  10.951000   11.540200
#
# [19156 rows x 683 columns]

# %%
X = X.iloc[:,(X.var(0)!=0).values]
Xtot = Xtot.iloc[:,(Xtot.var(0)!=0).values]

# %%
list(pathways.keys())
# Out:
# ['BIOCARTA_DEATH_PATHWAY',
#  'BIOCARTA_CELLCYCLE_PATHWAY',
#  'BIOCARTA_ERK_PATHWAY',
#  'BIOCARTA_NFKB_PATHWAY',
#  'BIOCARTA_P53_PATHWAY',
#  'BIOCARTA_RAS_PATHWAY',
#  'BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY',
#  'REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATION',
#  'REACTOME_DNA_REPAIR',
#  'UAMS17',
#  'THALIDOMIDE']

# %%
n_on = on + list(pathways.keys())

# %%
scaler = preprocessing.StandardScaler().fit(X[on].values)
X_scaled = scaler.transform(X[on].values)

totscaler = preprocessing.StandardScaler().fit(Xtot[on].values)
Xtot_scaled = totscaler.transform(Xtot[on].values)

# %%
clf = svm.SVC()
#clf = clf.fit(X_scaled, Y)
scores = cross_val_score(clf, X_scaled, Y, cv=100)
print(scores.mean())

clf = LogisticRegression()
clf = clf.fit(X_scaled, Y)
scores = cross_val_score(clf, X_scaled[:, abs(clf.coef_[0])>0.2], Y, cv=100)
print(scores.mean())

clf = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=1, max_iter=800)
clf = clf.fit(X_scaled, Y)
scores = cross_val_score(clf, X_scaled, Y, cv=100)
print(scores.mean())

## F1 score
## ROC curve
# Out:
# 0.7025
# 0.7200000000000002
# 0.7125000000000001

# %%
coef = clf.coef_[0]

# %%
np.array(n_on)[abs(coef)>0.2]
# Out:
# array(['age', 'stage', 'PHF19', 'BIOCARTA_P53_PATHWAY',
#        'BIOCARTA_RAS_PATHWAY',
#        'REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATION',
#        'REACTOME_DNA_REPAIR', 'UAMS17'], dtype='<U65')

# %%
Y_pred = clf.predict(X_scaled)

# %%
from sksurv.nonparametric import kaplan_meier_estimator

# %%
kaplan_meier_estimator

# %%
clinical_data
# Out:
#            age     sex  stage  survival_days  has_survived  pfs_days  \
# Patient
# MMRF_1021   54  Female    1.0           1575             0       623
# MMRF_1029   46    Male    1.0            995             0       995
# MMRF_1030   65  Female    1.0           1572             0      1572
# MMRF_1031   62    Male    1.0           1581             0      1329
# MMRF_1032   76    Male    2.0            934             1       908
# ...        ...     ...    ...            ...           ...       ...
# MMRF_2535   46  Female    3.0            354             0       354
# MMRF_2554   65    Male    1.0            271             1       271
# MMRF_2557   83    Male    3.0            325             1       131
# MMRF_2562   66    Male    2.0            269             0       199
# MMRF_2596   73  Female    1.0            139             1       139
#
#            has_progressed to_pred
# Patient
# MMRF_1021               1   FALSE
# MMRF_1029               0   FALSE
# MMRF_1030               0   FALSE
# MMRF_1031               1   FALSE
# MMRF_1032               1   FALSE
# ...                   ...     ...
# MMRF_2535               1    TRUE
# MMRF_2554               1    TRUE
# MMRF_2557               1    TRUE
# MMRF_2562               1    TRUE
# MMRF_2596               1    TRUE
#
# [377 rows x 8 columns]

# %%
for pred_event in (1, 0):
    mask_treat = Y_pred == pred_event
    time_treatment, survival_prob_treatment = kaplan_meier_estimator(
        unc_clinical_data["is_deceased"][mask_treat].astype(bool), 
        unc_clinical_data["survival_days"][mask_treat])

    plt.step(time_treatment, survival_prob_treatment, where="post",
             label="EVENT_PREDICTION = %s" % pred_event)

    plt.ylabel("est. probability of survival $\hat{S}(t)$")
    plt.xlabel("time $t$")
    plt.legend(loc="best")

# %%
plt.show()

# %%
def show_metrics(clf, X_scaled, Y):
    Y_pred = clf.predict(X_scaled)
    prec, rec, f1, _ = precision_recall_fscore_support(Y, Y_pred, average='weighted')
    plot_roc_curve(clf, X_scaled, Y)
    plt.show()
    for pred_event in (1, 0):
        mask_treat = Y_pred == pred_event
        time_treatment, survival_prob_treatment = kaplan_meier_estimator(
            unc_clinical_data["is_deceased"][mask_treat].astype(bool), 
            unc_clinical_data["survival_days"][mask_treat])

        plt.step(time_treatment, survival_prob_treatment, where="post",
                 label="EVENT_PREDICTION = %s" % pred_event)

    plt.ylabel("est. probability of survival $\hat{S}(t)$")
    plt.xlabel("time $t$")
    plt.legend(loc="best")
    plt.show()
    cross_scores = cross_val_score(clf, X_scaled, Y, cv=100)
    print('precision, recall, f1_score:')
    print(prec, rec, f1 )
    print('k-fold CV score:')
    print(cross_scores.mean())

# %%
clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X.values, Y)
show_metrics(clf, X.values, Y)
# Out:
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-164-776fb41ef3d6> in <module>
#       1 clf = RandomForestClassifier(n_estimators=10)
#       2 clf = clf.fit(X.values, Y)
# ----> 3 show_metrics(clf, X.values, Y)
#
# <ipython-input-163-9312d7aee066> in show_metrics(clf, X_scaled, Y)
#      17     plt.legend(loc="best")
#      18     plt.show()
# ---> 19     cross_scores = cross_val_score(clf, X_scaled, Y, cv=100)
#      20     print('precision, recall, f1_score:')
#      21     print(prec, rec, f1 )
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     443     scorer = check_scoring(estimator, scoring=scoring)
#     444
# --> 445     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     446                                 scoring={'score': scorer}, cv=cv,
#     447                                 n_jobs=n_jobs, verbose=verbose,
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     248     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     249                         pre_dispatch=pre_dispatch)
# --> 250     results = parallel(
#     251         delayed(_fit_and_score)(
#     252             clone(estimator), X, y, scorers, train, test, verbose, None,
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     596             estimator.fit(X_train, **fit_params)
#     597         else:
# --> 598             estimator.fit(X_train, y_train, **fit_params)
#     599
#     600     except Exception as e:
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
#     389                 delayed(_parallel_build_trees)(
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     167                                                         indices=indices)
#     168
# --> 169         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     170     else:
#     171         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~/miniconda3/envs/gae/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     392                                            min_impurity_split)
#     393
# --> 394         builder.build(self.tree_, X, y, sample_weight)
#     395
#     396         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
clf = RandomForestClassifier(n_estimators=100)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)
# Out:
# precision, recall, f1_score:
# 1.0 1.0 1.0
# k-fold CV score:
# 0.6608333333333334

# %%
clf = KNeighborsClassifier(n_neighbors=10)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)

# %%
clf = KNeighborsClassifier(n_neighbors=15)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)
# Out:
# precision, recall, f1_score:
# 0.7230974207845697 0.7347480106100795 0.7069343128736194
# k-fold CV score:
# 0.7058333333333334

# %%
clf = svm.SVC(C=1)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)
# Out:
# precision, recall, f1_score:
# 0.7347550934402367 0.7400530503978779 0.7067534323806117
# k-fold CV score:
# 0.7041666666666666

# %%
clf = svm.SVC(C=1)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)
# Out:
# precision, recall, f1_score:
# 0.7347550934402367 0.7400530503978779 0.7067534323806117
# k-fold CV score:
# 0.7041666666666666

# %%
clf = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=1, max_iter=800, C=0.2)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)
# Out:
# precision, recall, f1_score:
# 0.7021325124473028 0.7161803713527851 0.6733681420528662
# k-fold CV score:
# 0.7041666666666666

# %%
clf = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=1, max_iter=800, C=0.2)
clf = clf.fit(X_scaled, Y)
show_metrics(clf, X_scaled, Y)
# Out:
# precision, recall, f1_score:
# 0.7021325124473028 0.7161803713527851 0.6733681420528662
# k-fold CV score:
# 0.7041666666666666

# %%
from genepy import rna
# %reload_ext autoreload
# %autoreload 2

# %%
gsea = await rna.gsva(rna_data.T, geneset_file="../data/MMpathways.gmt", method='ssgsea')
# Out:
# you need to have R installed with GSVA and GSEABase library installed
# CompletedProcess(args='Rscript /Users/jeremie/Documents/Projects/BroadInstitute/genepy/genepy/rna/ssGSEA.R /tmp/data_genepyhelper_gsva.csv ../data/MMpathways.gmt ssgsea', returncode=0, stdout=b'Estimating ssGSEA scores for 11 gene sets.\n[1] "Calculating ranks..."\n[1] "Calculating absolute values from ranks..."\n\r  |                                                                            \r  |                                                                      |   0%\r  |                                                                            \r  |                                                                      |   1%\r  |                                                                            \r  |=                                                                     |   1%\r  |                                                                            \r  |=                                                                     |   2%\r  |                                                                            \r  |==                                                                    |   2%\r  |                                                                            \r  |==                                                                    |   3%\r  |                                                                            \r  |==                                                                    |   4%\r  |                                                                            \r  |===                                                                   |   4%\r  |                                                                            \r  |===                                                                   |   5%\r  |                                                                            \r  |====                                                                  |   5%\r  |                                                                            \r  |====                                                                  |   6%\r  |                                                                            \r  |=====                                                                 |   6%\r  |                                                                            \r  |=====                                                                 |   7%\r  |                                                                            \r  |=====                                                                 |   8%\r  |                                                                            \r  |======                                                                |   8%\r  |                                                                            \r  |======                                                                |   9%\r  |                                                                            \r  |=======                                                               |   9%\r  |                                                                            \r  |=======                                                               |  10%\r  |                                                                            \r  |=======                                                               |  11%\r  |                                                                            \r  |========                                                              |  11%\r  |                                                                            \r  |========                                                              |  12%\r  |                                                                            \r  |=========                                                             |  12%\r  |                                                                            \r  |=========                           ...

# %%
gsea
# Out:
#                                                     MMRF_1021  MMRF_1029  \
# BIOCARTA_DEATH_PATHWAY                               0.334025   0.385600
# BIOCARTA_CELLCYCLE_PATHWAY                           0.263254   0.255618
# BIOCARTA_ERK_PATHWAY                                 0.353344   0.334111
# BIOCARTA_NFKB_PATHWAY                                0.267654   0.268335
# BIOCARTA_P53_PATHWAY                                 0.398249   0.436573
# BIOCARTA_RAS_PATHWAY                                 0.421278   0.426604
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.183811   0.175504
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.325229   0.326934
# REACTOME_DNA_REPAIR                                  0.337922   0.321687
# UAMS17                                               0.320217   0.338686
# THALIDOMIDE                                         -0.392721  -0.309584
#
#                                                     MMRF_1030  MMRF_1031  \
# BIOCARTA_DEATH_PATHWAY                               0.373136   0.355098
# BIOCARTA_CELLCYCLE_PATHWAY                           0.256062   0.358889
# BIOCARTA_ERK_PATHWAY                                 0.337636   0.336148
# BIOCARTA_NFKB_PATHWAY                                0.263450   0.231004
# BIOCARTA_P53_PATHWAY                                 0.456137   0.453244
# BIOCARTA_RAS_PATHWAY                                 0.416789   0.415184
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.186027   0.252148
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.328930   0.336716
# REACTOME_DNA_REPAIR                                  0.332686   0.365583
# UAMS17                                               0.308884   0.367831
# THALIDOMIDE                                         -0.238122  -0.286233
#
#                                                     MMRF_1032  MMRF_1033  \
# BIOCARTA_DEATH_PATHWAY                               0.372045   0.358233
# BIOCARTA_CELLCYCLE_PATHWAY                           0.276184   0.215206
# BIOCARTA_ERK_PATHWAY                                 0.313722   0.328460
# BIOCARTA_NFKB_PATHWAY                                0.259294   0.268432
# BIOCARTA_P53_PATHWAY                                 0.453924   0.436039
# BIOCARTA_RAS_PATHWAY                                 0.409306   0.396516
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.186838   0.199183
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.326241   0.330853
# REACTOME_DNA_REPAIR                                  0.328461   0.337022
# UAMS17                                               0.331009   0.291236
# THALIDOMIDE                                         -0.278037  -0.337842
#
#                                                     MMRF_1037  MMRF_1038  \
# BIOCARTA_DEATH_PATHWAY                               0.366674   0.396631
# BIOCARTA_CELLCYCLE_PATHWAY                           0.242182   0.228073
# BIOCARTA_ERK_PATHWAY                                 0.353370   0.338778
# BIOCARTA_NFKB_PATHWAY                                0.268004   0.260051
# BIOCARTA_P53_PATHWAY                                 0.458544   0.417711
# BIOCARTA_RAS_PATHWAY                                 0.424999   0.422295
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.203157   0.190971
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.326273   0.339992
# REACTOME_DNA_REPAIR                                  0.339835   0.328767
# UAMS17                                               0.325201   0.316089
# THALIDOMIDE                                         -0.254444  -0.336560
#
#                                                     MMRF_1045  MMRF_1048  ...  \
# BIOCARTA_DEATH_PATHWAY                               0.352911   0.373366  ...
# BIOCARTA_CELLCYCLE_PATHWAY                           0.226473   0.283246  ...
# BIOCARTA_ERK_PATHWAY                                 0.333813   0.352967  ...
# BIOCARTA_NFKB_PATHWAY                                0.252540   0.257722  ...
# BIOCARTA_P53_PATHWAY                                 0.419977   0.397572  ...
# BIOCARTA_RAS_PATHWAY                                 0.399303   0.427259  ...
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.160837   0.202405  ...
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.327952   0.335397  ...
# REACTOME_DNA_REPAIR                                  0.342589   0.345063  ...
# UAMS17                                               0.294355   0.265919  ...
# THALIDOMIDE                                         -0.344943  -0.322236  ...
#
#                                                     MMRF_2039  MMRF_1229  \
# BIOCARTA_DEATH_PATHWAY                               0.333351   0.372462
# BIOCARTA_CELLCYCLE_PATHWAY                           0.356947   0.220272
# BIOCARTA_ERK_PATHWAY                                 0.362993   0.319443
# BIOCARTA_NFKB_PATHWAY                                0.273722   0.257537
# BIOCARTA_P53_PATHWAY                                 0.431002   0.399825
# BIOCARTA_RAS_PATHWAY                                 0.444890   0.397018
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.243144   0.180659
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.331001   0.338118
# REACTOME_DNA_REPAIR                                  0.355734   0.338477
# UAMS17                                               0.342150   0.312177
# THALIDOMIDE                                         -0.283032  -0.365768
#
#                                                     MMRF_1778  MMRF_2419  \
# BIOCARTA_DEATH_PATHWAY                               0.376526   0.345168
# BIOCARTA_CELLCYCLE_PATHWAY                           0.284410   0.248551
# BIOCARTA_ERK_PATHWAY                                 0.382018   0.312526
# BIOCARTA_NFKB_PATHWAY                                0.271704   0.232746
# BIOCARTA_P53_PATHWAY                                 0.420606   0.407893
# BIOCARTA_RAS_PATHWAY                                 0.424603   0.387949
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.278469   0.178063
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.325468   0.333455
# REACTOME_DNA_REPAIR                                  0.374544   0.340791
# UAMS17                                               0.381194   0.289920
# THALIDOMIDE                                         -0.327207  -0.392966
#
#                                                     MMRF_1518  MMRF_1242  \
# BIOCARTA_DEATH_PATHWAY                               0.373808   0.379148
# BIOCARTA_CELLCYCLE_PATHWAY                           0.381929   0.360873
# BIOCARTA_ERK_PATHWAY                                 0.360071   0.361226
# BIOCARTA_NFKB_PATHWAY                                0.289841   0.261659
# BIOCARTA_P53_PATHWAY                                 0.393723   0.378128
# BIOCARTA_RAS_PATHWAY                                 0.427585   0.453812
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.313851   0.220343
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.332022   0.342513
# REACTOME_DNA_REPAIR                                  0.395514   0.357407
# UAMS17                                               0.414753   0.393306
# THALIDOMIDE                                         -0.234895  -0.310499
#
#                                                     MMRF_1309  MMRF_1587  \
# BIOCARTA_DEATH_PATHWAY                               0.374008   0.380769
# BIOCARTA_CELLCYCLE_PATHWAY                           0.291652   0.385860
# BIOCARTA_ERK_PATHWAY                                 0.357055   0.347817
# BIOCARTA_NFKB_PATHWAY                                0.264177   0.263605
# BIOCARTA_P53_PATHWAY                                 0.432209   0.480828
# BIOCARTA_RAS_PATHWAY                                 0.411126   0.393247
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.166196   0.288489
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.324886   0.352271
# REACTOME_DNA_REPAIR                                  0.317505   0.411027
# UAMS17                                               0.301332   0.421296
# THALIDOMIDE                                         -0.383798  -0.195953
#
#                                                     MMRF_2089  MMRF_1284
# BIOCARTA_DEATH_PATHWAY                               0.319101   0.377560
# BIOCARTA_CELLCYCLE_PATHWAY                           0.357974   0.245349
# BIOCARTA_ERK_PATHWAY                                 0.354843   0.339479
# BIOCARTA_NFKB_PATHWAY                                0.185550   0.342763
# BIOCARTA_P53_PATHWAY                                 0.343003   0.444086
# BIOCARTA_RAS_PATHWAY                                 0.425648   0.422719
# BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY       0.301758   0.160200
# REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROT...   0.322473   0.313924
# REACTOME_DNA_REPAIR                                  0.408543   0.310138
# UAMS17                                               0.405731   0.305100
# THALIDOMIDE                                         -0.227302  -0.253438
#
# [11 rows x 683 columns]

# %%
X[gsea.index] = gsea.T.loc[X.index]
# Out:
# [WARNING] /Users/jeremie/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
X[X.columns[-20:]]
# Out:
#              UBE2E2  LAMTOR5     TAF4B    TMEM71     NCOA7     HSBP1   age  \
# MMRF_1889   4.37895  57.7361   6.27239  0.121006  16.46210  18.50180  62.0
# MMRF_1383   7.80850  26.4266   5.65751  0.033997  13.27650   3.99897  73.0
# MMRF_1164  22.54530  67.5897   5.72740  2.582780   7.01156  14.88220  70.0
# MMRF_1846   7.31119  31.4234   6.33410  0.028593   2.79843   6.05114  58.0
# MMRF_2119   9.45772  44.1179   4.64468  0.266574  10.46050  10.87880  60.0
# ...             ...      ...       ...       ...       ...       ...   ...
# MMRF_1408  16.37050  40.1954   7.23519  0.140981  21.43560  12.53840  62.0
# MMRF_2562  21.45910  59.0201  22.89330  0.045621   9.18464  16.43650  66.0
# MMRF_1654   9.05918  49.8076   7.58806  3.458290  14.40630  23.64220  86.0
# MMRF_1393   6.07203  24.2424   6.67436  0.200702  20.98150   3.20694  58.0
# MMRF_1758  10.81600  48.6331   3.52267  0.096764  19.39380  12.34580  72.0
#
#            sex  stage  BIOCARTA_DEATH_PATHWAY  BIOCARTA_CELLCYCLE_PATHWAY  \
# MMRF_1889  1.0    3.0                0.310103                    0.354064
# MMRF_1383  0.0    1.0                0.360504                    0.232801
# MMRF_1164  1.0    3.0                0.358628                    0.251418
# MMRF_1846  0.0    1.0                0.389509                    0.222910
# MMRF_2119  1.0    3.0                0.362340                    0.331262
# ...        ...    ...                     ...                         ...
# MMRF_1408  1.0    1.0                0.357035                    0.222898
# MMRF_2562  0.0    2.0                0.395897                    0.268533
# MMRF_1654  0.0    2.0                0.341955                    0.313834
# MMRF_1393  1.0    2.0                0.363227                    0.290747
# MMRF_1758  1.0    2.0                0.343204                    0.265159
#
#            BIOCARTA_ERK_PATHWAY  BIOCARTA_NFKB_PATHWAY  BIOCARTA_P53_PATHWAY  \
# MMRF_1889              0.308494               0.195685              0.432356
# MMRF_1383              0.331542               0.256218              0.352677
# MMRF_1164              0.329156               0.322770              0.368675
# MMRF_1846              0.358513               0.323775              0.388649
# MMRF_2119              0.309469               0.249849              0.364313
# ...                         ...                    ...                   ...
# MMRF_1408              0.336339               0.263248              0.431429
# MMRF_2562              0.342420               0.268853              0.419649
# MMRF_1654              0.322646               0.283161              0.367308
# MMRF_1393              0.349512               0.331546              0.434073
# MMRF_1758              0.309792               0.234199              0.421518
#
#            BIOCARTA_RAS_PATHWAY  \
# MMRF_1889              0.393406
# MMRF_1383              0.412726
# MMRF_1164              0.431262
# MMRF_1846              0.415364
# MMRF_2119              0.394249
# ...                         ...
# MMRF_1408              0.408557
# MMRF_2562              0.431302
# MMRF_1654              0.379171
# MMRF_1393              0.477134
# MMRF_1758              0.373073
#
#            BORTEZOMIB_ABNORMALITY_OF_CHROMOSOME_STABILITY  \
# MMRF_1889                                        0.301803
# MMRF_1383                                        0.170903
# MMRF_1164                                        0.166462
# MMRF_1846                                        0.166240
# MMRF_2119                                        0.220010
# ...                                                   ...
# MMRF_1408                                        0.185449
# MMRF_2562                                        0.204652
# MMRF_1654                                        0.191129
# MMRF_1393                                        0.169364
# MMRF_1758                                        0.200976
#
#            REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATION  \
# MMRF_1889                                           0.330683
# MMRF_1383                                           0.336702
# MMRF_1164                                           0.325997
# MMRF_1846                                           0.325691
# MMRF_2119                                           0.335049
# ...                                                      ...
# MMRF_1408                                           0.336493
# MMRF_2562                                           0.338550
# MMRF_1654                                           0.332932
# MMRF_1393                                           0.326758
# MMRF_1758                                           0.330261
#
#            REACTOME_DNA_REPAIR    UAMS17  THALIDOMIDE
# MMRF_1889             0.395166  0.460024    -0.217642
# MMRF_1383             0.336859  0.323534    -0.360505
# MMRF_1164             0.312260  0.319430    -0.409392
# MMRF_1846             0.330902  0.295239    -0.277175
# MMRF_2119             0.348689  0.353614    -0.336137
# ...                        ...       ...          ...
# MMRF_1408             0.344826  0.248054    -0.362613
# MMRF_2562             0.343921  0.338640    -0.324612
# MMRF_1654             0.343712  0.312036    -0.357570
# MMRF_1393             0.314857  0.232872    -0.367307
# MMRF_1758             0.352576  0.318668    -0.329467
#
# [377 rows x 20 columns]

# %%
clf = RandomForestClassifier(n_estimators=40)
clf = clf.fit(X_scaled, Y)
scores = cross_val_score(clf, X_scaled, Y, cv=10)
print(scores.mean())

clf = DecisionTreeClassifier()
clf = clf.fit(X_scaled, Y)

scores = cross_val_score(clf, X_scaled, Y, cv=10)
print(scores.mean())
# Out:
# 0.6899004267425319
# 0.5491465149359886
